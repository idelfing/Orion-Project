# %% [markdown]
# <a href="https://colab.research.google.com/github/idelfing/Orion-Project/blob/main/Prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd

# %%
fecha_idk = pd.to_datetime(f'2025/11/01')
fecha_idk
# Out:
# Timestamp('2025-11-01 00:00:00')

# %%
a = "test conflict"
